# %% [markdown]
# ## Import

# %%
from data_aug.data_aug import *
from data_aug.bbox_util import *
import numpy as np 
import cv2 
import matplotlib.pyplot as plt 
import pickle as pkl
# %matplotlib inline

# %% [markdown]
# ## Helper classes

# %%
class AugGenerator:
    """How to use: set_input_dir(dir) -> read_input() -> set_sequences(sequences) -> set_default_resolution((w,h))-> execute()"""
    def to_yolov3_format(self, bboxes):
        _bboxes = []
        w_img,h_img = self.w, self.h
        for bbox in bboxes:
            w_box, h_box = bbox[2]-bbox[0], bbox[3]-bbox[1]
            _bbox = [int(bbox[4]),bbox[0]+w_box/2,bbox[1]+h_box/2,w_box,h_box]
            _bbox = [_bbox[0],_bbox[1]/w_img,_bbox[2]/h_img,_bbox[3]/w_img,_bbox[4]/h_img]
            _bboxes.append(_bbox)
        return _bboxes
    def revert_format(self, bboxes):
        _bboxes = []
        w_img,h_img = self.w, self.h
        for bbox in bboxes:
            _bbox = [bbox[1]*w_img,bbox[2]*h_img,bbox[3]*w_img,bbox[4]*h_img,bbox[0]]
            w_box, h_box = _bbox[2], _bbox[3]
            _bbox = [_bbox[0]-w_box/2, _bbox[1]-h_box/2,_bbox[0]+w_box/2, _bbox[1]+h_box/2, _bbox[4]]
            _bboxes.append(_bbox)
        return _bboxes
    def set_input(self, imgPaths, labelPaths):
        self.imgPaths = imgPaths
        self.labelPaths = labelPaths
        return self
    def read_input(self):
        self.labels = []
        for path in self.labelPaths:
            with open(path,'r') as txt:
                bboxes = []
                for line in txt.readlines():
                    bboxes.append([int(i) for i in line.split(' ')])                  
                bboxes = np.array(bboxes,dtype='float')
            self.labels.append(bboxes)
        return self
    def set_default_resolution(self, size):
        self.w, self.h = size[0],size[1]
        return self
    def set_sequences(self, sequences):
        self.sequences = sequences
        return self
    def get_default_sequences(self):
        sequences = [Rotate(0),Rotate(45),Rotate(-45),RandomHorizontalFlip(1)]
        tmp = []
        for seq in sequences:
            tmp = tmp + [Sequence([seq,RandomHSV((50,50),0,(-10,-10))])]
        sequences = sequences+tmp
        return sequences
    def execute(self, outDir):
        n = len(self.imgPaths)
        for i in range(n):
            path = self.imgPaths[i]
            img = cv2.imread(path)
            bboxes = self.labels[i]
            indx = path.index('/')
            name = path[indx+1:path.index('.')]
            print(i,n,path)

            for j in range(len(self.sequences)):
                # do transformation
                augImg, augBboxes = self.sequences[j](img.copy(),np.array(bboxes))
                # transform to yolov3 format
                augBboxes = self.to_yolov3_format(augBboxes)
                # save transformed image+'aug%03d'%j
                cv2.imwrite('%s/%saug%03d.jpg'%(outDir,name,j),augImg)
                # save transformed bbox to label file
                with open('%s/%saug%03d.txt'%(outDir,name,j),'w', newline='\n') as txt:
                    for bbox in augBboxes:
                        line = ' '.join([str(item) for item in bbox])+'\n'
                        txt.write(line)
        return self

# %%
class TrainTestSpliter:
    """Use this class to quickly split the output of the AugGenerator input train/test subfolders.
        How to use: set_input(dir) -> split()"""
    def set_input(self, dir):
        self.imgPaths = sorted(glob.glob('%s/%s'%(dir,'*.jpg')))
        self.labelPaths = sorted(glob.glob('%s/%s'%(dir,'*.txt')))
        self.dir = dir
        return self
    def split(self, trainRatio=.8):
        from shutil import move
        from os import mkdir
        import numpy as np
        
        dir_train, dir_test = self.dir+'/train', self.dir+'/test'
        try: os.mkdir(dir_train)
        except: pass
        try: os.mkdir(dir_test)
        except: pass
        n = len(self.imgPaths)
        nums = int(n*trainRatio)
        indices = np.linspace(0,n-1,num=nums,dtype='int').tolist()
        # print(nums,n)
        # print(indices)
        for i in range(n):
            src_img, src_txt = self.imgPaths[i], self.labelPaths[i]
            name = src_img[src_img.rindex('/')+1:src_img.rindex('.')]
            dir_dest = None
            try:
                indices.index(i) # checks if i in indices list
                dir_dest = dir_train
            except:
                dir_dest = dir_test
            # print(i,src_img,'%s/%s.jpg'%(dir_dest,name))
            move(src_img,'%s/%s.jpg'%(dir_dest,name))
            move(src_txt,'%s/%s.txt'%(dir_dest,name))

# %%
class AugValidator:
    def set_default_resolution(self, sz):
        self.w, self.h = sz[0],sz[1]
        return self
    def set_input(self, imgPaths, labelPaths):
        self.imgPaths, self.labelPaths = imgPaths, labelPaths
        return self
    def read_input(self):
        self.labels = []
        for path in self.labelPaths:
            with open(path,'r') as txt:
                bboxes = []
                for line in txt.readlines():
                    nums = line.split(' ')
                    bboxes.append([int(nums[0])]+[float(x) for x in nums[1:]])                  
            self.labels.append(bboxes)
        return self
    def revert_format(self):
        self.rlabels = []
        w_img,h_img = self.w, self.h
        for bboxes in self.labels:
            rbboxes = []
            for bbox in bboxes:
                _bbox = [bbox[1]*w_img,bbox[2]*h_img,bbox[3]*w_img,bbox[4]*h_img,bbox[0]]
                w_box, h_box = _bbox[2], _bbox[3]
                _bbox = [_bbox[0]-w_box/2, _bbox[1]-h_box/2,_bbox[0]+w_box/2, _bbox[1]+h_box/2, _bbox[4]]
                rbboxes.append(_bbox)
            rbboxes = np.array(rbboxes,dtype='int')
            self.rlabels.append(rbboxes)
        return self

# %% [markdown]
# # Augmenting

# %%
import glob
sz = (640,360)  # sets dimensions to resize images
input = [sorted(glob.glob('input/*.jpg')), sorted(glob.glob('input/*.txt'))]    # gets all image and label files
g = AugGenerator()
g.set_input(input[0],input[1]).read_input().set_default_resolution(sz).set_sequences(g.get_default_sequences()).execute('output-test')  # chaining methods to augments images
# Out:
# 45
# -45
# 194 586 input/tung3100000743.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 195 586 input/tung3100000757.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 196 586 input/tung3100000770.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 197 586 input/tung3100000780.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 198 586 input/tung3100000788.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 199 586 input/tung3100000792.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 200 586 input/tung3100000799.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 201 586 input/tung3100000817.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 202 586 input/tung3100000836.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 203 586 input/tung3100000846.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 204 586 input/tung3100000853.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 205 586 input/tung3100000861.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 206 586 input/tung3100000870.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 207 586 input/tung3100000875.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 208 586 input/tung3100000880.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 209 586 input/tung3100000882.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 210 586 input/tung3100000886.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 211 586 input/tung3100000888.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 212 586 input/tung3100000892.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 213 586 input/tung3100000900.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 214 586 input/tung3100000907.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 215 586 input/tung3100000914.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 216 586 input/tung3100000994.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 217 586 input/tung3100001132.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 218 586 input/tung3100001140.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 219 586 input/tung3100001152.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 220 586 input/tung3100001168.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 221 586 input/tung3100001175.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 222 586 input/tung3100001188.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 223 586 input/tung3100001210.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 224 586 input/tung3100001219.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 225 586 input/tung4200000237.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 226 586 input/tung4200000350.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 227 586 input/tung4200000632.jpg
# 0
# 45
# -45
# 0
# 45
# -45
#
jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 549 586 input/tung6400001363.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 550 586 input/tung6400001375.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 551 586 input/tung6400001394.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 552 586 input/tung6400001416.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 553 586 input/tung6400001426.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 554 586 input/tung6400001438.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 555 586 input/tung6400001447.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 556 586 input/tung6400001454.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 557 586 input/tung6400001456.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 558 586 input/tung6400001605.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 559 586 input/tung6400001689.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 560 586 input/tung6400001835.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 561 586 input/tung6400001853.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 562 586 input/tung6400001877.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 563 586 input/tung6400001900.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 564 586 input/tung6400001937.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 565 586 input/tung6400001953.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 566 586 input/tung6400001975.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 567 586 input/tung6400001995.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 568 586 input/tung6400002038.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 569 586 input/tung6400002052.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 570 586 input/tung6400002070.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 571 586 input/tung6400002118.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 572 586 input/tung6400002130.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 573 586 input/tung6400002162.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 574 586 input/tung6400002184.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 575 586 input/tung6400002384.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 576 586 input/tung6400002400.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 577 586 input/tung6400002421.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 578 586 input/tung6400002425.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 579 586 input/tung6400002434.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 580 586 input/tung6400002437.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 581 586 input/tung6400002443.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 582 586 input/tung6400002447.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 583 586 input/tung6400002454.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 584 586 input/tung6400002462.jpg
# 0
# 45
# -45
# 0
# 45
# -45
# 585 586 input/tung6400002470.jpg
# 0
# 45
# -45
# 0
# 45
# -45

# %% [markdown]
# # Split to train/test datasets

# %%
spt = TrainTestSpliter().set_input('output-test').split()

# %%
a = len(os.listdir('output-test/train'))
b = len(os.listdir('output-test/test'))
print('train',a,'test',b,a+b)
# Out:
# train 7500 test 1876 9376

# %%
# %%bash
# mv output members-dataset-vinh
# zip -r members-dataset-vinh.zip members-dataset-vinh
# Out:
# %)
#   adding: members-dataset-vinh/train/vinh-200000378aug014.jpg (deflated 3%)
#   adding: members-dataset-vinh/train/vinh-200000210aug023.txt (deflated 50%)
#   adding: members-dataset-vinh/train/vinh-200000387aug006.jpg (deflated 0%)
#   adding: members-dataset-vinh/train/vinh00000325aug015.txt (deflated 55%)
#   adding: members-dataset-vinh/train/vinh-200000396aug006.txt (deflated 47%)
#   adding: members-dataset-vinh/train/vinh-200000378aug021.jpg (deflated 0%)
#   adding: members-dataset-vinh/train/vinh00000590aug022.jpg (deflated 3%)
#   adding: members-dataset-vinh/train/vinh-200000267aug003.jpg (deflated 3%)
#   adding: members-dataset-vinh/train/vinh-200000243aug021.jpg (deflated 0%)
#   adding: members-dataset-vinh/train/vinh-200000378aug021.txt (deflated 50%)
#   adding: members-dataset-vinh/train/vinh00000610aug013.jpg (deflated 7%)
#   adding: members-dataset-vinh/train/vinh00000315aug009.txt (deflated 54%)
#   adding: members-dataset-vinh/train/vinh-200000405aug001.jpg (deflated 3%)
#   adding: members-dataset-vinh/train/vinh-200000264aug004.txt (deflated 48%)
#   adding: members-dataset-vinh/train/vinh00000380aug004.jpg (deflated 2%)
#   adding: members-dataset-vinh/train/vinh00000535aug007.jpg (deflated 3%)
#   adding: members-dataset-vinh/train/vinh-200000360aug000.jpg (deflated 0%)
#   adding: members-dataset-vinh/train/vinh00000335aug001.txt (deflated 55%)
#   adding: members-dataset-vinh/train/vinh00000340aug022.jpg (deflated 3%)
#   adding: members-dataset-vinh/train/vinh-200000324aug009.txt (deflated 48%)
#   adding: members-dataset-vinh/train/vinh00000535aug002.jpg (deflated 2%)
#   adding: members-dataset-vinh/train/vinh00000350aug021.txt (deflated 50%)
#   adding: members-dataset-vinh/train/vinh-200000234aug011.jpg (deflated 3%)
#   adding: members-dataset-vinh/train/vinh-200000237aug012.jpg (deflated 2%)
#   adding: members-dataset-vinh/train/vinh-200000333aug010.jpg (deflated 8%)
#   adding: members-dataset-vinh/train/vinh00000610aug020.txt (deflated 55%)
#   adding: members-dataset-vinh/train/vinh00000365aug022.txt (deflated 63%)
#   adding: members-dataset-vinh/train/vinh-200000261aug011.jpg (deflated 3%)
#   adding: members-dataset-vinh/train/vinh-200000369aug015.txt (deflated 41%)
#   adding: members-dataset-vinh/train/vinh-200000324aug014.jpg (deflated 3%)
#   adding: members-dataset-vinh/train/vinh00000570aug002.jpg (deflated 2%)
#   adding: members-dataset-vinh/train/vinh00000560aug010.txt (deflated 55%)
#   adding: members-dataset-vinh/train/vinh00000355aug020.txt (deflated 55%)
#   adding: members-dataset-vinh/train/vinh00000375aug014.jpg (deflated 3%)
#   adding: members-dataset-vinh/train/vinh-200000207aug009.jpg (deflated 2%)
#   adding: members-dataset-vinh/train/vinh00000555aug001.jpg (deflated 2%)
#   adding: members-dataset-vinh/train/vinh-200000237aug021.txt (deflated 54%)
#   adding: members-dataset-vinh/train/vinh-200000210aug005.jpg (deflated 0%)
#   adding: members-dataset-vinh/train/vinh00000360aug018.jpg (deflated 2%)
#   adding: members-dataset-vinh/train/vinh00000330aug015.jpg (deflated 2%)
#   adding: members-dataset-vinh/train/vinh00000615aug004.txt (deflated 55%)
#   adding: members-dataset-vinh/train/vinh-200000264aug023.txt (deflated 50%)
#   adding: members-dataset-vinh/train/vinh00000345aug005.txt (deflated 60%)
#   adding: members-dataset-vinh/train/vinh-200000378aug001.jpg (deflated 3%)
#   adding: members-dataset-vinh/train/vinh-200000261aug016.txt (deflated 48%)
#   adding: members-dataset-vinh/train/vinh-200000267aug002.txt (deflated 48%)
#   adding: members-dataset-vinh/train/vinh00000370aug005.jpg (deflated 0%)
#   adding: members-dataset-vinh/train/vinh-200000405aug006.jpg (deflated 0%)
#   adding: members-dataset-vinh/train/vinh00000315aug012.txt (deflated 54%)
#   adding: members-dataset-vinh/train/vinh00000535aug017.jpg (deflated 2%)
#   adding: members-dataset-vinh/train/vinh00000585aug021.txt (deflated 51%)
#   adding: members-dataset-vinh/train/vinh-200000240aug015.jpg (deflated 2%)
#   adding: members-dataset-vinh/train/vinh-200000210aug015.txt (deflated 48%)
#   adding: members-dataset-vinh/train/vinh-200000258aug021.txt (deflated 52%)
#   adding: members-dataset-vinh/train/vinh00000335aug006.jpg (deflated 0%)
#   adding: members-dataset-vinh/train/vinh00000575aug020.txt (deflated 55%)
#   adding: members-dataset-vinh/train/vinh-200000387aug016.jpg (deflated 8%)
#   adding: members-dataset-vinh/train/vinh-200000240aug013.txt (deflated 48%)
#   adding: members-dataset-vinh/train/vinh-200000297aug023.jpg (deflated 0%)
#   adding: members-dataset-vinh/train/vinh-200000243aug006.jpg (deflated 0%)
#   adding: members-dataset-vinh/train/vinh-200